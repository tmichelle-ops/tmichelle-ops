# %% [markdown]
# <a href="https://colab.research.google.com/github/tmichelle-ops/tmichelle-ops/blob/main/Data%20and%20Decision%20Making.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, ECON 6485!")
# Out:
# Hello, ECON 6485!

# %%
import pandas as pd
data = {
"StudyHours":[5,8,3,10],
"ExamScore":[75,88,65,95]
}
df = pd.DataFrame(data)
df

#This creates a simple dataset using Python.
#Dr. Erdal Asker (University of West Georgia) ECON 4485/6485 Summer 2026 10 / 19
# Out:
#    StudyHours  ExamScore
# 0           5         75
# 1           8         88
# 2           3         65
# 3          10         95

# %%
import matplotlib.pyplot as plt
plt.scatter(df['StudyHours'],
df['ExamScore'])
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")
plt.show()

# %%
tuition = 8500
students = 1200
total_revenue = tuition * students
print(total_revenue)
# Out:
# 10200000

# %%
# !pip list
# Out:
# Package                                  Version
# ---------------------------------------- -------------------
# absl-py                                  1.4.0
# accelerate                               1.13.0
# access                                   1.1.10.post3
# affine                                   2.4.0
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.6.2
# aiohttp                                  3.13.5
# aiosignal                                1.4.0
# aiosqlite                                0.22.1
# alabaster                                1.0.0
# albucore                                 0.0.24
# albumentations                           2.0.8
# ale-py                                   0.11.2
# alembic                                  1.18.4
# altair                                   5.5.0
# annotated-doc                            0.0.4
# annotated-types                          0.7.0
# ...
